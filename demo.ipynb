# %% [markdown]
# print your name
#
# # shift + enter (shortcut to run your cell)
#
# whatever text you want to have in this file will be in MARKDOWN
#
# code will be written in CODE

# %%
# ceil 

print("snehitha")
# Out:
# snehitha

# %% [markdown]
# install python
# install vscode
# create folder on desktop
# try to create .pynb file in that folder
# install kernel and connect IT (what python version)
# create markdown and code cell(to run them user)
