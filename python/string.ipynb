# %%
###Write a program that converts the string "python programming" into uppercase.
text="python programming"
print(text.upper())
# Out:
# PYTHON PROGRAMMING

# %%
###Write a program that converts the string "WELCOME TO PYTHON" into lowercase.
text = "WELCOME TO PYTHON"
print(text.lower())
# Out:
# welcome to python

# %%
###Write a program that converts "my name is john" so that every word starts with a capital
text="my name is john"
print(text.title())
# Out:
# My Name Is John

# %%
###Write a program that converts "python is fun" so that only the first letter of the sentence is capitalized.
text = "python is fun"
print(text.capitalize())
# Out:
# Python is fun

# %%
###Write a program that checks whether the string "HELLO" is completely in uppercase
text="HELLO"
print(text.isupper())
# Out:
# True

# %%
###Write a program that checks whether the string "python" is completely in lowercase
text = "python"
print(text.islower())

# %%
###Write a program that checks whether the string "Python123" contains only alphabets.
text="Python123"
print(text.isalpha())
# Out:
# False

# %%
###Write a program that checks whether the string "Python123" contains only letters and numbers
text="Python123"
print(text.isalnum())
# Out:
# True

# %%
###Write a program that checks whether the string "123456" contains only numeric characters.
text="123456"
print(text.isnumeric())
# Out:
# True

# %%
###Write a program that checks whether the string "Python Programming" starts with "Python".
text="Python Programming"
print(text.startswith("Python"))
# Out:
# True

# %%
###Write a program that checks whether the string "python.pdf" ends with ".pdf".
text="Python.pdf"
print(text.endswith(".pdf"))
# Out:
# True

# %%
###Write a program that removes spaces from both sides of the string " Hello World ".
text=" Hello "
print(text.strip())
# Out:
# Hello

# %%
####Write a program that removes spaces only from the left side of the string " Python".
text="   Python   "
print(text.lstrip())
# Out:
# Python

# %%
###Write a program that removes spaces only from the right side of the string "Python ".
text="   Python   "
print(text.rstrip())
# Out:
#    Python

# %%
###Write a program that right-aligns the string "Hi" in a width of 8 characters using '*' as the filling character.
text="Hi"
print(text.center(8,"*"))
# Out:
# ***Hi***

# %%
###Write a program that left-aligns the string "Hi" in a width of 8 characters using '*' as the filling character.
text="Hi"
print(text.ljust(5,"*"))
# Out:
# Hi***

# %%
###Write a program that converts the string "25" into a 5-digit number by adding zeros to the left.
text="25"
print(text.zfill(5))
# Out:
# 00025

# %%
###Write a program that splits the string "apple,banana,mango,orange" into a list using the comma , as the separator.
text="apple,mango,banana,guava"
print(text.split())
# Out:
# ['apple,mango,banana,guava']

# %%
####Write a program that finds the index position of the letter "o" in the string "Programming".
text="programming"
print(text.index("o"))
# Out:
# 2

# %%
###Write a program that counts how many times the letter "a" appears in the string "banana".
text="banana"
print(text.count("a"))
# Out:
# 3

# %%
###Write a program that replaces the word "Java" with "Python" in the string "I am learning Java".
text="I am learning Java"
print(text.replace("Java","Python"))
# Out:
# I am learning Python

# %%
####Take a string from the user and count how many times the letter "e" appears.

text=input("Enter a value")
print(text.count("e"))
# Out:
# 2

# %%
###Take a sentence from the user and split it into words.
text=input("Enter a sentence")
print(text.split())
# Out:
# ['I', 'am', 'learning', 'python', 'programming']

# %%
###Take a string from the user and replace all spaces with hyphens (-).
text=input("Enter a sentence")
print(text.replace(" ","-"))
# Out:
# welcome-to-python-programming

# %%
###Take a string from the user and remove the extra spaces from both sides.
text = input("Enter a value")
print(text.strip())
# Out:
# wel

# %%
###Take a string from the user and check whether it contains only alphabets.
text=input("Enter a value")
print(text.isnumeric())
# Out:
# False

# %%
####Take a string from the user and convert it into title case.
text=input("Enter a value")
print(text.title())
print(text.capitalize())
# Out:
# Python Programming
# Python programming

# %%
###Write a Python program to display the string "Python" in a field of 15 characters, with the text placed exactly in the middle. Use * as the filling character.
text="Python"
print(text.center(15,"*"))
# Out:
# *****Python****

# %%
###Write a Python program to display the word "Welcome" so that it appears at the left side of a field of 20 characters. Fill the remaining space with -.
text="Welcome"
print(text.ljust(20,"-"))
# Out:
# Welcome-------------

# %%
###Write a Python program to display the word "Hello" so that it appears at the right side of a field of 12 characters. Fill the remaining space with #.
text="Hello"
print(text.rjust(12,"#"))
# Out:
# #######Hello

# %%
###Write a Python program to print "AI" in the center of a field of 10 characters, using = as the filling character.
text="AI"
print(text.center(10,"="))
# Out:
# ====AI====

# %%
###Write a Python program to print "Python" at the left end of a field of 15 characters, using * as the filling character.
text = "python"
print(text.ljust(15,"*"))
# Out:
# python*********

# %%
text = "python"
print(text.center(12,"*"))
# Out:
# ***python***

# %%
text1 = "data engineering"
text2 = "machine learning"

print(text1.split()[0].ljust(8,"*")+text2.split()[1])
# Out:
# data****learning

# %%
text1="data engineering"
text2="machine learning"

print(text1.split()[0].ljust(8,"*")+text1.split()[1].ljust(18,"*")+text2.split()[0].ljust(9,"*")+text2.split()[1].ljust(20,"*"))
# Out:
# data****engineering*******machine**learning************

# %%
#  ***engineering*****machine*

text1 = "data engineering"
text2 = "machine learning"
print(text1.split()[1].center(18,"*") + text2.split()[0].center(9,"*"))
# Out:
# ***engineering*****machine*
